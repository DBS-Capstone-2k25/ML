# %%
# !pip install tensorflowjs
# Out:
# Collecting tensorflowjs
#   Downloading tensorflowjs-4.22.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: flax>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.10.3)
# Requirement already satisfied: importlib_resources>=5.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (6.5.2)
# Requirement already satisfied: jax>=0.4.13 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.4.33)
# Requirement already satisfied: jaxlib>=0.4.13 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.4.33)
# Requirement already satisfied: tensorflow<3,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (2.18.0)
# Requirement already satisfied: tf-keras>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (2.18.0)
# Requirement already satisfied: tensorflow-decision-forests>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (1.11.0)
# Requirement already satisfied: six<2,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (1.17.0)
# Requirement already satisfied: tensorflow-hub>=0.16.1 in /usr/local/lib/python3.11/dist-packages (from tensorflowjs) (0.16.1)
# Collecting packaging~=23.1 (from tensorflowjs)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (1.26.4)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (1.1.0)
# Requirement already satisfied: optax in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.2.4)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.6.4)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.1.71)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (14.0.0)
# Requirement already satisfied: typing_extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (4.13.1)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (6.0.2)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.11/dist-packages (from flax>=0.7.2->tensorflowjs) (0.1.8)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.13->tensorflowjs) (0.4.1)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.13->tensorflowjs) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.13->tensorflowjs) (1.15.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (18.1.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (75.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.5.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (3.12.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow<3,>=2.13.0->tensorflowjs) (0.37.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.2.3)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (0.45.1)
# Requirement already satisfied: wurlitzer in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (3.1.1)
# Requirement already satisfied: ydf in /usr/local/lib/python3.11/dist-packages (from tensorflow-decision-forests>=1.5.0->tensorflowjs) (0.9.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow<3,>=2.13.0->tensorflowjs) (0.14.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow<3,>=2.13.0->tensorflowjs) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=11.1->flax>=0.7.2->tensorflowjs) (2.19.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.1.3)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.11/dist-packages (from optax->flax>=0.7.2->tensorflowjs) (0.1.88)
# Requirement already satisfied: etils[epy] in /usr/local/lib/python3.11/dist-packages (from optax->flax>=0.7.2->tensorflowjs) (1.12.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (1.6.0)
# Requirement already satisfied: humanize in /usr/local/lib/python3.11/dist-packages (from orbax-checkpoint->flax>=0.7.2->tensorflowjs) (4.11.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->tensorflow-decision-forests>=1.5.0->tensorflowjs) (2025.2)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chex>=0.1.87->optax->flax>=0.7.2->tensorflowjs) (1.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.7.2->tensorflowjs) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow<3,>=2.13.0->tensorflowjs) (3.0.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (2025.3.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.7.2->tensorflowjs) (3.21.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.23.2->flax>=0.7.2->tensorflowjs) (2024.2.0)
# Downloading tensorflowjs-4.22.0-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 kB 2.2 MB/s eta 0:00:00a 0:00:01
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: packaging, tensorflowjs
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 3.5.0 requires fsspec[http]<=2024.12.0,>=2023.1.0, but you have fsspec 2025.3.2 which is incompatible.
# nilearn 0.11.1 requires scikit-learn>=1.4.0, but you have scikit-learn 1.2.2 which is incompatible.
# pandas-gbq 0.26.1 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# bigframes 1.36.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.5 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Successfully installed packaging-23.2 tensorflowjs-4.22.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os
import shutil
import random
from pathlib import Path

import tensorflow as tf
import tensorflowjs as tfjs
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
# Out:
# 2025-04-30 08:28:14.567529: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746001694.771216      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746001694.830990      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# <p style="margin:0px;">🌲 Try <a href="https://ydf.readthedocs.io/en/latest/" target="_blank">YDF</a>, the successor of
#     <a href="https://www.tensorflow.org/decision_forests" target="_blank">TensorFlow
#         Decision Forests</a> using the same algorithms but with more features and faster
#     training!
# </p>
# <div style="display: flex; flex-wrap: wrap; margin:5px;max-width: 880px;">
#     <div style="flex: 1; border-radius: 10px; background-color: F0F0F0; padding: 5px;">
#         <p
#             style="font-weight: bold; margin:0px;text-align: center;border-bottom: 1px solid #C0C0C0;margin-bottom: 4px;">
#             Old code</p>
#         <pre style="overflow-wrap: anywhere; overflow: auto; margin:0px;font-size: 9pt;">
# import tensorflow_decision_forests as tfdf
#
# tf_ds = tfdf.keras.pd_dataframe_to_tf_dataset(ds, label="l")
# model = tfdf.keras.RandomForestModel(label="l")
# model.fit(tf_ds)
# </pre>
#     </div>
#     <div style="width: 5px;"></div>
#     <div style="flex: 1; border-radius: 10px; background-color: F0F0F0; padding: 5px;">
#         <p
#             style="font-weight: bold; margin:0px;text-align: center;border-bottom: 1px solid #C0C0C0;margin-bottom: 4px;">
#             New code</p>
#         <pre style="overflow-wrap: anywhere; overflow: auto; margin:0px;font-size: 9pt;">
# import ydf
#
# model = ydf.RandomForestLearner(label="l").train(ds)
# </pre>
#     </div>
# </div>
# <p style="margin:0px;font-size: 9pt;">(Learn more in the <a
#         href="https://ydf.readthedocs.io/en/latest/tutorial/migrating_to_ydf/" target="_blank">migration
#         guide</a>)</p>

# %%
print(tf.__version__)
# Out:
# 2.18.0

# %%
source_dir = '/kaggle/input/garbage-classification-v2/garbage-dataset'

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2  # Membagi 20% untuk validasi
)

# Membaca data training dan validation menggunakan split
train_generator = train_datagen.flow_from_directory(
    source_dir, 
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training'  # Menggunakan subset training (80% data)
)

validation_generator = train_datagen.flow_from_directory(
    source_dir,  # Ganti dengan path folder dataset
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation'  # Menggunakan subset validation (20% data)
)
# Out:
# Found 15813 images belonging to 10 classes.
# Found 3949 images belonging to 10 classes.

# %%
early_stop=EarlyStopping(monitor='val_loss',patience=10)
checkpoint=ModelCheckpoint(filepath='/kaggle/working/best.keras',monitor='val_loss',save_best_only=True,mode='auto')

# %%
base_model = MobileNetV2(weights='imagenet', include_top=False)

base_model.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x) 
x = Dense(1024, activation='relu')(x)
predictions = Dense(train_generator.num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /tmp/ipykernel_31/1040116440.py:1: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(weights='imagenet', include_top=False)
# I0000 00:00:1746001985.985444      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1746001985.986136      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
history = model.fit(
    train_generator,
    # steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=10, 
    validation_data=validation_generator,
    # validation_steps=validation_generator.samples // validation_generator.batch_size,
    callbacks=[early_stop,checkpoint]
)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746001997.884647     126 service.cc:148] XLA service 0x7de5d41117f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1746001997.885614     126 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1746001997.885646     126 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1746001998.752414     126 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   1/495 ━━━━━━━━━━━━━━━━━━━━ 1:55:59 14s/step - accuracy: 0.0938 - loss: 2.7302
# I0000 00:00:1746002002.858985     126 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 168s 312ms/step - accuracy: 0.8382 - loss: 0.5188 - val_accuracy: 0.9142 - val_loss: 0.2601
# Epoch 2/10
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 63s 125ms/step - accuracy: 0.9451 - loss: 0.1629 - val_accuracy: 0.9063 - val_loss: 0.3122
# Epoch 3/10
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 61s 121ms/step - accuracy: 0.9651 - loss: 0.0975 - val_accuracy: 0.9288 - val_loss: 0.2623
# Epoch 4/10
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 61s 122ms/step - accuracy: 0.9831 - loss: 0.0543 - val_accuracy: 0.9131 - val_loss: 0.3127
# Epoch 5/10
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 60s 120ms/step - accuracy: 0.9842 - loss: 0.0431 - val_accuracy: 0.9202 - val_loss: 0.3204
# Epoch 6/10
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 61s 121ms/step - accuracy: 0.9912 - loss: 0.0268 - val_accuracy: 0.9195 - val_loss: 0.3461
# Epoch 7/10
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 61s 122ms/step - accuracy: 0.9892 - loss: 0.0308 - val_accuracy: 0.9205 - val_loss: 0.3496
# Epoch 8/10
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 62s 124ms/step - accuracy: 0.9903 - loss: 0.0288 - val_accuracy: 0.9134 - val_loss: 0.4023
# Epoch 9/10
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 63s 125ms/step - accuracy: 0.9903 - loss: 0.0300 - val_accuracy: 0.9248 - val_loss: 0.3817
# Epoch 10/10
# 495/495 ━━━━━━━━━━━━━━━━━━━━ 61s 123ms/step - accuracy: 0.9924 - loss: 0.0215 - val_accuracy: 0.9286 - val_loss: 0.3544

# %%
train_generator.class_indices.keys()
# Out:
# dict_keys(['battery', 'biological', 'cardboard', 'clothes', 'glass', 'metal', 'paper', 'plastic', 'shoes', 'trash'])

# %%
loss, accuracy = model.evaluate(validation_generator)

print(f'Loss: {loss}')
print(f'Akurasi: {accuracy}')
# Out:
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 12s 99ms/step - accuracy: 0.9297 - loss: 0.3380
# Loss: 0.3544290065765381
# Akurasi: 0.9285895228385925

# %%
plt.figure(figsize=(12, 6))

# Plot akurasi
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Akurasi Training')
plt.plot(history.history['val_accuracy'], label='Akurasi Validation')
plt.title('Akurasi Model')
plt.xlabel('Epoch')
plt.ylabel('Akurasi')
plt.legend(loc='lower right')

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Loss Training')
plt.plot(history.history['val_loss'], label='Loss Validation')
plt.title('Loss Model')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

# Menampilkan plot
plt.tight_layout()
plt.show()

# %%
model.save('my_model.h5')

# %%
model.export('saved_model')
# Out:
# Saved artifact at 'saved_model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, None, None, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   138431283733968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138431282544080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753180432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138431282543504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138431282544272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138431282543696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753182352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753180240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753181008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753181968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753182160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753181200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753182928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753183696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753183312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753185808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753186576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753185616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753187536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753187152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753188304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753189264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753186768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753187920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753189072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753190608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753191952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753192144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753191760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753190992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753192528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753193872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753194064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753193680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753192912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753194448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753195792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753195984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753195600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753194832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429753193296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749249040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749248272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749249232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749248464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749248656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749251536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749251728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749251344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749249616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749252112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749253456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749253648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749253264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749252496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749254032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749255376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749255568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749255184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749254416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749255952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749257296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749257488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749257104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749256336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749257872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749259216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749259408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749259024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749258256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749259792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749261136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749261328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749260944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749260176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749261712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749263056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749263248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749262864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749262096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749260560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749625104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749625680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749263632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749264016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749626064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749627408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749627600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749627216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749626448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749627984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749629328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749629520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749629136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749628368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749629904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749631248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749631440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749631056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749630288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749631824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749633168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749633360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749632976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749632208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749633744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749635088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749635280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749634896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749634128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749635664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749637008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749637200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749636816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749636048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749637584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749638928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749639120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749638736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749637968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749639504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749640848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749638352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749640656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429749639888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750133008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750134352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750134544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750134160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750133584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750134928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750136272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750136464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750136080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750135312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750136848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750138192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750138384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750138000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750137232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750138768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750140112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750140304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750139920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750139152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750140688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750142032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750142224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750141840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750141072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750142608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750143952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750144144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750143760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750142992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750144528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750145872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750146064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750145680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750144912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750146448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750147792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750147984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750147600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750146832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750145296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628465808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628465232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750148368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429750148752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628466384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628467728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628467920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628467536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628466768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628468304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628469648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628469840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628469456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628468688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628470224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628471568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628471760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628471376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628470608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628472144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628473488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628473680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628473296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628472528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628474064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628475408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628475600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628475216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628474448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628475984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628477328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628477520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628477136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628476368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628477904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628479248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628479440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628479056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628478288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628479824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628481168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628478672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628480976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628480208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628974096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628974672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628974864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628974480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628973712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628975248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628976592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628976784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628976400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628975632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628977168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628978512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628978704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628978320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628977552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628979088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628980432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628980624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628980240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628979472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628981008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628982352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628982544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628982160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628981392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628982928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628984272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628984464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628984080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628983312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628984848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628986192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628986384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628986000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628985232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628986768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628988112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628988304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628987920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628987152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628985616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429615849744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429615850320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628988688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429628989072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429615850704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429615852048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429615852240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429615851856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429615851088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429615853968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429615855120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429615855312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138429615855888: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
tfjs.converters.save_keras_model(model, 'model_tfjs')
# Out:
# failed to lookup keras version from the file,
#     this is likely a weight only file

# %%
# !zip -r /kaggle/working/model.zip /kaggle/working/
# Out:
#   adding: kaggle/working/ (stored 0%)
#   adding: kaggle/working/my_model.h5 (deflated 9%)
#   adding: kaggle/working/saved_model/ (stored 0%)
#   adding: kaggle/working/saved_model/assets/ (stored 0%)
#   adding: kaggle/working/saved_model/variables/ (stored 0%)
#   adding: kaggle/working/saved_model/variables/variables.index (deflated 78%)
#   adding: kaggle/working/saved_model/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: kaggle/working/saved_model/fingerprint.pb (stored 0%)
#   adding: kaggle/working/saved_model/saved_model.pb (deflated 90%)
#   adding: kaggle/working/best.keras (deflated 8%)
#   adding: kaggle/working/model_tfjs/ (stored 0%)
#   adding: kaggle/working/model_tfjs/group1-shard4of4.bin (deflated 7%)
#   adding: kaggle/working/model_tfjs/group1-shard1of4.bin (deflated 7%)
#   adding: kaggle/working/model_tfjs/group1-shard2of4.bin (deflated 7%)
#   adding: kaggle/working/model_tfjs/group1-shard3of4.bin (deflated 7%)
#   adding: kaggle/working/model_tfjs/model.json (deflated 97%)
#   adding: kaggle/working/.virtual_documents/ (stored 0%)
